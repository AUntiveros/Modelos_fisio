# %% [markdown]
# # Bases de datos

# %% [markdown]
# ## Variables que se pueden usar:
# - Fuente: https://www.sciencedirect.com/science/article/pii/S2590113325000288

# %% [markdown]
# ### Climáticas
# - Temperatura promedio
# - Temperatura mínima
# - Temperatura máxima
# - Humedad relativa
# - Lluvia (mm)
# - Presión superficial?
# - Velocidad del viento a 50 m?

# %% [markdown]
# ### Sociedromgráficas
# - Densidad poblacional
# - PBI
# - Ingresos nacionales
# - Tasa de incidencia de pobreza
# - Tasa de alfabetización en adultos
# - Total de desempleados
# - Acceso a electricidad
# - Crecimiento poblacional

# %% [markdown]
# ### Variables ambientales
# - Área forestal (del total)
# - Tierras agrícoles (del total)
# - Área cultivables (del total)

# %% [markdown]
# ## datos_abiertos_vigilancia_dengue_2000_2023
# - Enfermedad: Solo Dengue
# - Años:  2000 - 2023
# - Escala: Nacional
# - Enlace:  https://datosabiertos.gob.pe/dataset/vigilancia-epidemiológica-de-las-zoonosis

# %%
import pandas as pd

df = pd.read_csv('dataset/datos_abiertos_vigilancia_dengue_2000_2023.csv')
df.head()
# Out:
#   departamento      provincia                distrito  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN
#
#                     enfermedad   ano  semana diagnostic tipo_dx  diresa  \
# 0  DENGUE SIN SIGNOS DE ALARMA  2000      47      A97.0       P    10.0
# 1  DENGUE SIN SIGNOS DE ALARMA  2000      40      A97.0       P    10.0
# 2  DENGUE SIN SIGNOS DE ALARMA  2000      48      A97.0       C    10.0
# 3  DENGUE SIN SIGNOS DE ALARMA  2000      37      A97.0       P    10.0
# 4  DENGUE SIN SIGNOS DE ALARMA  2000      42      A97.0       C    10.0
#
#    ubigeo  edad tipo_edad sexo
# 0  100605     9         A    M
# 1  100605    18         A    F
# 2  100604    32         A    F
# 3  100604    40         A    F
# 4  100606    16         A    M

# %% [markdown]
# ----

# %% [markdown]
# ## datos_abiertos_vigilancia_malaria_2009_2023
# - Enfermedad: Malaria
# - Años:  2009 - 2023 (otro archivo va desde 2000 a 2008)
# - Escala: Nacional
# - Enlace: https://datosabiertos.gob.pe/dataset/vigilancia-epidemiológica-de-malaria

# %%
import pandas as pd

df = pd.read_csv('dataset/datos_abiertos_vigilancia_malaria_2009_2023.csv')
df.head()
# Out:
#     departamento  provincia          distrito            enfermedad   ano  \
# 0         TUMBES  ZARUMILLA      AGUAS VERDES  MALARIA POR P. VIVAX  2009
# 1         ANCASH      CASMA  BUENA VISTA ALTA  MALARIA POR P. VIVAX  2009
# 2  MADRE DE DIOS       MANU     MADRE DE DIOS  MALARIA POR P. VIVAX  2009
# 3          PIURA    SULLANA           SULLANA  MALARIA POR P. VIVAX  2009
# 4         ANCASH     YUNGAY        RANRAHIRCA  MALARIA POR P. VIVAX  2009
#
#    semana diagnostic tipo_dx  diresa  ubigeo  edad tipo_edad sexo
# 0      15        B51       C      24  240302    32         A    M
# 1      18        B51       C       2   20802     7         A    M
# 2      19        B51       C      17  170203    17         A    M
# 3      21        B51       C      31  200601    53         A    F
# 4      22        B51       C       2   22006    24         A    M

# %% [markdown]
# ## DATA_SET_DENGUE_PUIRA
# - Enfermedad: Dengue
# - Años:  2023
# - Escala: región de Piura
# - Enlace: https://datosabiertos.gob.pe/dataset/casos-de-dengue-en-la-región-piura-gobierno-regional-piura

# %%
import pandas as pd

df = pd.read_csv('dataset/DATA_SET_DENGUE_PUIRA.csv')
df.head()
# Out:
#    FECHA_CORTE  FECHA_INGRESO  ANIO DEPARTAMENTO PROVINCIA      DISTRITO  \
# 0     20230517       20230502  2023        PIURA   SULLANA       SULLANA
# 1     20230517       20230411  2023        PIURA  MORROPON  BUENOS AIRES
# 2     20230517       20230510  2023        PIURA     PIURA      CASTILLA
# 3     20230517       20230504  2023        PIURA   SULLANA       SULLANA
# 4     20230517       20230504  2023        PIURA     PIURA      CASTILLA
#
#    UBIGEO            LOCALIDAD                      CENTRO_SALUD  \
# 0  200601                  NaN  ALBERTO LEOPOLDO BARTON THOMPSON
# 1  200402         CARRASQUILLO         ALBERTO SABOGAL SOLOGUREN
# 2  200104             CASTILLA                     ALTO TRUJILLO
# 3  200601              SULLANA           AUNA CLINICA MIRAFLORES
# 4  200104  A.H. LA PRIMAVERA I           AUNA CLINICA MIRAFLORES
#
#                                UUID  EDAD TIPO_EDAD       SEXO  \
# 0  047CA87878645E12654481B85023BB3A    52         A  MASCULINO
# ...

# %% [markdown]
# ## Datos_Sierra (son 4 páginas)
# - Variables:
#    - Incidencia pobreza
#    - Desnutrición crónica
#    - Tasa de Analfabetismo
# - Años:  2025
# - Escala: Nacional (Sierra?)
# - Enlace: https://sigrid.cenepred.gob.pe/sigridv3/escenarios

# %%
#%pip install openpyxl
# Son 4 páginas
import pandas as pd

df = pd.read_excel('dataset/Datos_Sierra.xlsx', header = 1)
df.head()
# Out:
# c:\Users\kamey\anaconda3\envs\laboratorio\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#   Departamento Provincia  Ubigeo distrital  Distrito  \
# 0          NaN       NaN               NaN       NaN
# 1       ANCASH  ASUNCION           20402.0  ACOCHACA
# 2       ANCASH  ASUNCION           20401.0    CHACAS
# 3       ANCASH   CARHUAZ           20602.0  ACOPAMPA
# 4       ANCASH   CARHUAZ           20603.0   AMASHCA
#
#      Factor de Susceptibilidad               Unnamed: 5           Unnamed: 6  \
# 0  1/ Condición del territorio  2/ N° Eventos mov. masa  Valor de Susceptib.
# 1                           A5                        8               0.3947
# 2                           A5                       13               0.4271
# 3                           A5                        2               0.3749
# ...

# %% [markdown]
# ##
# - Enfermedad:
# - Años:
# - Escala:
# - Enlace:

# %% [markdown]
# ##
# - Enfermedad:
# - Años:
# - Escala:
# - Enlace:

# %% [markdown]
# # Manejo datos faltantes

# %% [markdown]
# ## Datos planos

# %% [markdown]
# ### Assessing dengue forecasting methods: a comparative study of statistical models and machine learning techniques in Rio de Janeiro, Brazil
# - ¿Qué se realizó?: Nada, XGBoost puede manejar valores faltantes.
# - Cita: "XGBoost’s ability to handle missing values and incorporate regularization makes it well-suited for dengue forecasting"
# - Enlace: https://pmc.ncbi.nlm.nih.gov/articles/PMC11984044/

# %% [markdown]
# ### Multivariate forecasting of dengue infection in Bangladesh: evaluating the influence of data downscaling on machine learning predictive accuracy
# - ¿Qué procede?: Imputación usando la media
# - Cita: "A small number of missing values in the sunshine hour dataset were addressed by imputing them using the mean value for the same month from the previous three years".
# - Enlace: https://bmcinfectdis.biomedcentral.com/articles/10.1186/s12879-025-11159-z

# %% [markdown]
# ### Modelo de machine learning para predicción de brotes de leishmaniasis en la provincia de La Convención
# - ¿Qué procede?: Imputación con interpolación lineal, promedio o eliminación
# - Cita: (son 3)
# - Enlace: https://repositorioacademico.upc.edu.pe/bitstream/handle/10757/676440/Baptista_OE.pdf;jsessionid=762A1975C5C32A4C84F46D1E2541D8A0?sequence=1

# %% [markdown]
# ### Epidemiología de la Infección por el Virus del Dengue y Atención en los Establecimientos de Salud del Seguro Social de Salud, 2023-2024
# - ¿Qué procede?: Validar y comparar con registro original.
# - Cita: "Los datos faltantes e inconsistencias se verificaron para ser solucionados mediante un proceso sistemático que consistió en la identificación y validación de patrones de valores ausentes o incoherentes mediante la comparación con los registros originales"
# - Enlace: https://ietsi.essalud.gob.pe/wp-content/uploads/2024/12/RRI-11-2024-dengue.pdf

# %% [markdown]
# ### Development of data-driven machine learning models and their potential role in predicting dengue outbreak
# - ¿Qué procede?: Promedio (respecto a variable clima, para mismo mes, diferentes años)
# - Cita: "This method implies the replacement of missing values with average values of the same month in different years."
# - Enlace: https://journals.lww.com/jvbd/fulltext/2024/61040/development_of_data_driven_machine_learning_models.1.aspx

# %% [markdown]
# ### Precision Prediction for Dengue Fever in Singapore: A Machine Learning Approach Incorporating Meteorological Data
# - ¿Qué procede?: Usando R, se usí "mice" o la media.
# - Cita: " ‘mice’ was used for handling missing data"
# - Enlace: https://www.mdpi.com/2414-6366/9/4/72

# %% [markdown]
# ### An Efficient and Hybrid Antlion Optimization-Based Genetic Algorithm Assisted Machine Learning Technique: A Metaheuristic Approach for Dengue Prediction
# - ¿Qué procede?: Imputación con el dato más común.
# - Dato adicional: Se propone integrar ALO y GA para mejorar la precisión de la predicción de dengue.
# - Cita: (Está largo)
# - Enlace: https://www.jneonatalsurg.com/index.php/jns/article/view/2024/1925

# %% [markdown]
# ###
# - ¿Qué procede?:
# - Cita:
# - Enlace:

# %% [markdown]
# ## Imágenes

# %% [markdown]
# ### Hybrid Machine Learning Approach to Zero-Inflated Data Improves Accuracy of Dengue Prediction
# - ¿Qué procede?: Uso de método regresión ponderada localmente (LWR)
# - Cita: Additional processing to fill missing pixels in both LST and NDVI raster datasets was performed using the locally weighted regression (LWR) method in GRASS GIS
# - Enlace: https://journals.plos.org/plosntds/article?id=10.1371%2Fjournal.pntd.0012599

# %% [markdown]
# # Enlaces por revisar

# %% [markdown]
# ## Códigos o github

# %% [markdown]
# ### Un Github: "A reproducible ensemble machine learning approach to forecast dengue outbreaks"
# - Enlace: https://github.com/ESA-PhiLab/ESA-UNICEF_DengueForecastProject

# %% [markdown]
# ## Imágenes o videos (multimedia)

# %% [markdown]
# ### Datasets and Images:
# - Para imágenes del clima?
# - Enlace: https://data.giss.nasa.gov/

# %% [markdown]
# ## Datos planos (caracteres, números)

# %% [markdown]
# ### Leveraging hybrid machine learning and data fusion for accurate mapping of malaria cases using meteorological variables in western India
# - ¿Qué hace?
#     - Proponer modelo
#     - Proponer tratamiento de outliers
#     - Comparativa de modelos
# - Enlace: https://www.sciencedirect.com/science/article/pii/S2667305322001016

# %% [markdown]
# ### Visual crossing
# - ¿Qué? Hay dataset de clima, aún no sé cómo se usa
# - Enlace: https://www.visualcrossing.com/

# %% [markdown]
# ### Población total estimada 2025
# - ¿Qué?: Hay estadística, como población actual (histórica). Toca checar, hay más información.
# - Enlace: https://www.minsa.gob.pe/reunis/?op=1&niv=5&tbl=1

# %% [markdown]
# ### Datos metereológicos
# - ¿Qué?: Hay de temperatura máxima, mínima, humedad y precipitación
# - Problema: Se requiere permiso o crear cuenta?
# - Enlace: https://www.senamhi.gob.pe/site/descarga-datos/

# %% [markdown]
# ## Variados (otros o combinación de los anteriores)

# %% [markdown]
# ### World Bank Open data
# - Enlace: https://data.worldbank.org/

# %% [markdown]
# ### Hybrid machine learning method for classification and recommendation of vector-borne disease
# - ¿Qué?: Artículo de revisión y da el pipeline para crear el modelo. Evalúa algunos modelos ya creados.
# - Enlace: https://pdfs.semanticscholar.org/11b2/c4332ae233d59b5e3eafd400707ad847980e.pdf
